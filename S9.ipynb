# %% [markdown]
# # Diffusion models

# %%
import torch
import torch.nn as nn

# %%
x0 = torch.randn(8, 3, 32, 32)

batch_size = x0.shape[0]
noise = torch.rand_like(x0)

print(noise[0])
# Out:
# tensor([[[0.0262, 0.5641, 0.0956,  ..., 0.3054, 0.9637, 0.7063],
#          [0.0900, 0.5317, 0.9473,  ..., 0.0564, 0.0390, 0.5502],
#          [0.2920, 0.9598, 0.8349,  ..., 0.2069, 0.6200, 0.7742],
#          ...,
#          [0.4589, 0.1191, 0.7300,  ..., 0.2832, 0.6914, 0.0555],
#          [0.4685, 0.2580, 0.2017,  ..., 0.1148, 0.9469, 0.4283],
#          [0.9019, 0.6710, 0.8675,  ..., 0.0656, 0.6723, 0.9810]],
#
#         [[0.5811, 0.0181, 0.3674,  ..., 0.7208, 0.0391, 0.2800],
#          [0.9063, 0.5661, 0.7716,  ..., 0.8792, 0.0650, 0.0130],
#          [0.6117, 0.1273, 0.2744,  ..., 0.3311, 0.4437, 0.5148],
#          ...,
#          [0.4674, 0.1908, 0.1948,  ..., 0.7082, 0.1350, 0.7257],
#          [0.6815, 0.0662, 0.7224,  ..., 0.2789, 0.1924, 0.6713],
#          [0.0097, 0.6871, 0.0152,  ..., 0.2635, 0.7379, 0.4477]],
#
#         [[0.9199, 0.4283, 0.7785,  ..., 0.8299, 0.5389, 0.6328],
#          [0.5137, 0.4366, 0.5475,  ..., 0.4908, 0.8180, 0.9709],
# ...
